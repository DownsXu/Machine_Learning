# %%
# RandomForestClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_wine

# %matplotlib inline

# %%
# 导入数据集
wine = load_wine()

# %%
# 分离测试集和训练集
X_train, X_test, Y_train, Y_test = train_test_split(wine.data, wine.target, test_size=0.3)

# %%
# 建立模型
clf = DecisionTreeClassifier(random_state=0)
rfc = RandomForestClassifier(random_state=0)
clf.fit(X_train, Y_train)
rfc.fit(X_train, Y_train)
score_c = clf.score(X_test, Y_test)
score_r = rfc.score(X_test, Y_test)

# %%
print(f'DecisionTreeClassifier: {score_c}')
print(f'RandomForestClassifier: {score_r}')
# Out:
# DecisionTreeClassifier: 0.9074074074074074
# RandomForestClassifier: 0.9814814814814815

# %%
# 交叉验证
clf_l = []
rfc_l = []
for i in range(10):
    clf = DecisionTreeClassifier()
    rfc = RandomForestClassifier(n_estimators=25)
    clf_s = cross_val_score(clf, wine.data, wine.target, cv=10).mean()
    rfc_s = cross_val_score(rfc, wine.data, wine.target, cv=10).mean()
    clf_l.append(clf_s)
    rfc_l.append(rfc_s)
plt.plot(range(1, 11), clf_l, label='DecisionTreeClassifier')
plt.plot(range(1, 11), rfc_l, label='RandomForestClassifier')
plt.legend()
plt.show()

# %%
# from tqdm import tqdm
# # n_estimators的学习曲线
# superpa = []
# for i in tqdm(range(200)):
#     rfc = RandomForestClassifier(n_estimators=i+1, n_jobs=-1)
#     rfc_s = cross_val_score(rfc, wine.data, wine.target, cv=10).mean()
#     superpa.append(rfc_s)
# print(f'{max(superpa)}\n index: {superpa.index(max(superpa))}')
# plt.figure(figsize=[20, 5])
# plt.plot(range(1, 201), superpa)
# plt.show()

# %%
    rfc = RandomForestClassifier(n_estimators=25)
    rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=25)

# %%
score = rfc.score(X_test, Y_test)

# %%
score
# Out:
# 0.9629629629629629

# %%
rfc.apply(X_test)
# Out:
# array([[19,  7, 15, ..., 14, 19, 19],
#        [ 4,  1,  8, ...,  1, 13,  3],
#        [ 7,  4,  4, ...,  1, 13,  3],
#        ...,
#        [10,  5,  5, ...,  5,  5, 12],
#        [ 4,  4,  8, ..., 13, 13,  3],
#        [10,  5,  5, ...,  5,  5, 12]], dtype=int64)

# %%
rfc.predict(X_test)
# Out:
# array([0, 2, 2, 1, 1, 0, 2, 1, 1, 1, 2, 0, 1, 1, 0, 1, 2, 2, 2, 2, 0, 0,
#        2, 1, 2, 0, 0, 2, 0, 2, 2, 1, 0, 2, 1, 1, 2, 1, 0, 1, 2, 0, 1, 2,
#        0, 1, 0, 1, 0, 1, 1, 1, 2, 1])

# %%
rfc.predict_proba(X_test)
# Out:
# array([[1.  , 0.  , 0.  ],
#        [0.  , 0.  , 1.  ],
#        [0.  , 0.04, 0.96],
#        [0.  , 1.  , 0.  ],
#        [0.44, 0.52, 0.04],
#        [0.72, 0.24, 0.04],
#        [0.04, 0.16, 0.8 ],
#        [0.04, 0.88, 0.08],
#        [0.  , 1.  , 0.  ],
#        [0.08, 0.92, 0.  ],
#        [0.  , 0.  , 1.  ],
#        [1.  , 0.  , 0.  ],
#        [0.  , 1.  , 0.  ],
#        [0.  , 1.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.08, 0.92, 0.  ],
#        [0.04, 0.12, 0.84],
#        [0.  , 0.08, 0.92],
#        [0.  , 0.2 , 0.8 ],
#        [0.  , 0.  , 1.  ],
#        [1.  , 0.  , 0.  ],
#        [0.96, 0.04, 0.  ],
#        [0.08, 0.12, 0.8 ],
#        [0.4 , 0.52, 0.08],
#        [0.12, 0.28, 0.6 ],
#        [0.88, 0.08, 0.04],
#        [0.68, 0.24, 0.08],
#        [0.04, 0.2 , 0.76],
#        [0.92, 0.  , 0.08],
#        [0.  , 0.04, 0.96],
#        [0.  , 0.28, 0.72],
#        [0.  , 1.  , 0.  ],
#        [0.8 , 0.16, 0.04],
#        [0.08, 0.  , 0.92],
#        [0.  , 1.  , 0.  ],
#        [0.08, 0.8 , 0.12],
#        [0.04, 0.28, 0.68],
#        [0.24, 0.68, 0.08],
#        [1.  , 0.  , 0.  ],
#        [0.  , 1.  , 0.  ],
#        [0.04, 0.08, 0.88],
#        [0.88, 0.12, 0.  ],
#        [0.44, 0.56, 0.  ],
#        [0.  , 0.08, 0.92],
#        [0.76, 0.24, 0.  ],
#        [0.2 , 0.56, 0.24],
#        [0.96, 0.04, 0.  ],
#        [0.  , 0.72, 0.28],
#        [1.  , 0.  , 0.  ],
#        [0.  , 1.  , 0.  ],
#        [0.  , 0.96, 0.04],
#        [0.04, 0.96, 0.  ],
#        [0.  , 0.04, 0.96],
#        [0.  , 1.  , 0.  ]])
